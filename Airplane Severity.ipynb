# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_airplane = pd.read_csv('train.csv')
df_airplane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# Severity                   10000 non-null object
# Safety_Score               10000 non-null float64
# Days_Since_Inspection      10000 non-null int64
# Total_Safety_Complaints    10000 non-null int64
# Control_Metric             10000 non-null float64
# Turbulence_In_gforces      10000 non-null float64
# Cabin_Temperature          10000 non-null float64
# Accident_Type_Code         10000 non-null int64
# Max_Elevation              10000 non-null float64
# Violations                 10000 non-null int64
# Adverse_Weather_Metric     10000 non-null float64
# Accident_ID                10000 non-null int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 937.6+ KB

# %%
df_airplane.Accident_Type_Code = df_airplane.Accident_Type_Code.astype('object')
print((df_airplane.Accident_Type_Code.dtypes))
df_airplane.Accident_Type_Code.value_counts()
# Out:
# object
# 4    2057
# 2    1791
# 3    1752
# 7    1276
# 6    1215
# 1    1171
# 5     738
# Name: Accident_Type_Code, dtype: int64

# %%
sns.distplot(df_airplane.Cabin_Temperature)
# Out:
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df_airplane.Turbulence_In_gforces)
# Out:
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df_airplane.Control_Metric)
# Out:
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_airplane.Total_Safety_Complaints.value_counts()
# Out:
# 0     1281
# 1     1170
# 2     1058
# 3      886
# 4      659
# 5      629
# 7      565
# 6      560
# 8      414
# 9      324
# 10     323
# 11     256
# 12     243
# 13     240
# 14     208
# 15     173
# 19     120
# 17     117
# 20     100
# 16      99
# 22      97
# 21      78
# 18      73
# 23      47
# 25      31
# 29      31
# 24      26
# 28      21
# 30      20
# 26      19
# 35      19
# 34      18
# 33      16
# 31      16
# 44      15
# 27       8
# 37       7
# 40       7
# 54       6
# 39       5
# 32       5
# 38       5
# 43       3
# 36       2
# Name: Total_Safety_Complaints, dtype: int64

# %%
df_airplane.Days_Since_Inspection.value_counts()
# Out:
# 13    1117
# 14    1069
# 15    1067
# 12    1036
# 11    1009
# 16     743
# 10     721
# 17     563
# 9      535
# 8      512
# 18     384
# 19     286
# 7      273
# 20     216
# 6      200
# 21      65
# 5       64
# 4       58
# 3       29
# 23      26
# 22      14
# 2        8
# 1        5
# Name: Days_Since_Inspection, dtype: int64

# %%
df_airplane.Safety_Score.value_counts()
# Out:
# 38.447489    42
# 40.776256    38
# 28.904110    35
# 42.100457    35
# 39.817352    33
#              ..
# 50.639269     1
# 49.634703     1
# 73.789954     1
# 85.753425     1
# 23.333333     1
# Name: Safety_Score, Length: 1175, dtype: int64

# %%
sns.distplot(df_airplane.Safety_Score)
# Out:
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_airplane.Violations.value_counts()
# Out:
# 2    3793
# 1    2398
# 3    2376
# 0     696
# 4     675
# 5      62
# Name: Violations, dtype: int64

# %%
df_airplane.Severity.value_counts()
# Out:
# Highly_Fatal_And_Damaging                  3049
# Significant_Damage_And_Serious_Injuries    2729
# Minor_Damage_And_Injuries                  2527
# Significant_Damage_And_Fatalities          1695
# Name: Severity, dtype: int64

# %%
df_airplane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# Severity                   10000 non-null object
# Safety_Score               10000 non-null float64
# Days_Since_Inspection      10000 non-null int64
# Total_Safety_Complaints    10000 non-null int64
# Control_Metric             10000 non-null float64
# Turbulence_In_gforces      10000 non-null float64
# Cabin_Temperature          10000 non-null float64
# Accident_Type_Code         10000 non-null object
# Max_Elevation              10000 non-null float64
# Violations                 10000 non-null int64
# Adverse_Weather_Metric     10000 non-null float64
# Accident_ID                10000 non-null int64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 937.6+ KB

# %%
df_airplane.set_index('Accident_ID',inplace=True)
df_airplane.head()
# Out:
#                                             Severity  Safety_Score  \
# Accident_ID
# 7570                       Minor_Damage_And_Injuries     49.223744
# 12128                      Minor_Damage_And_Injuries     62.465753
# 2181               Significant_Damage_And_Fatalities     63.059361
# 5946         Significant_Damage_And_Serious_Injuries     48.082192
# 9054               Significant_Damage_And_Fatalities     26.484018
#
#              Days_Since_Inspection  Total_Safety_Complaints  Control_Metric  \
# Accident_ID
# 7570                            14                       22       71.285324
# 12128                           10                       27       72.288058
# 2181                            13                       16       66.362808
# 5946                            11                        9       74.703737
# 9054                            13                       25       47.948952
#
#              Turbulence_In_gforces  Cabin_Temperature Accident_Type_Code  \
# ...

# %% [markdown]
# ## Binning -- IGNORE

# %%
import numpy as np
bins = np.linspace(df_airplane.Cabin_Temperature.min(), df_airplane.Cabin_Temperature.max(), 10)
print(bins)
# Out:
# [74.74 77.27 79.8  82.33 84.86 87.39 89.92 92.45 94.98 97.51]

# %%
df_airplane['Cabin_Temperature_Bin'] = pd.cut(df_airplane['Cabin_Temperature'], bins)

# %%
df_airplane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 7570 to 9387
# Data columns (total 12 columns):
# Severity                   10000 non-null object
# Safety_Score               10000 non-null float64
# Days_Since_Inspection      10000 non-null int64
# Total_Safety_Complaints    10000 non-null int64
# Control_Metric             10000 non-null float64
# Turbulence_In_gforces      10000 non-null float64
# Cabin_Temperature          10000 non-null float64
# Accident_Type_Code         10000 non-null object
# Max_Elevation              10000 non-null float64
# Violations                 10000 non-null int64
# Adverse_Weather_Metric     10000 non-null float64
# Cabin_Temperature_Bin      9997 non-null category
# dtypes: category(1), float64(6), int64(3), object(2)
# memory usage: 947.7+ KB

# %%
bins_Safety_Score = np.linspace(df_airplane.Safety_Score.min(), df_airplane.Safety_Score.max(), 10)
bins_Days_Since_Inspection = np.linspace(df_airplane.Days_Since_Inspection.min(), df_airplane.Days_Since_Inspection.max(), 10)
bins_Total_Safety_Complaints = np.linspace(df_airplane.Total_Safety_Complaints.min(), df_airplane.Total_Safety_Complaints.max(), 10)
bins_Control_Metric = np.linspace(df_airplane.Control_Metric.min(), df_airplane.Control_Metric.max(), 10)
bins_Turbulence_In_gforces = np.linspace(df_airplane.Turbulence_In_gforces.min(), df_airplane.Turbulence_In_gforces.max(), 10)
bins_Adverse_Weather_Metric = np.linspace(df_airplane.Adverse_Weather_Metric.min(), df_airplane.Adverse_Weather_Metric.max(), 10)
bins_Max_Elevation = np.linspace(df_airplane.Max_Elevation.min(), df_airplane.Max_Elevation.max(), 10)

# %%
df_airplane['Safety_Score_Bin'] = pd.cut(df_airplane['Safety_Score'], bins_Safety_Score)
df_airplane['Days_Since_Inspection_Bin'] = pd.cut(df_airplane['Days_Since_Inspection'], bins_Days_Since_Inspection)
df_airplane['Total_Safety_Complaints_Bin'] = pd.cut(df_airplane['Total_Safety_Complaints'], bins_Total_Safety_Complaints)
df_airplane['Control_Metric_Bin'] = pd.cut(df_airplane['Control_Metric'], bins_Control_Metric)
df_airplane['Turbulence_In_gforces_Bin'] = pd.cut(df_airplane['Turbulence_In_gforces'], bins_Turbulence_In_gforces)
df_airplane['Adverse_Weather_Metric_Bin'] = pd.cut(df_airplane['Adverse_Weather_Metric'], bins_Adverse_Weather_Metric)
df_airplane['Max_Elevation_Bin'] = pd.cut(df_airplane['Max_Elevation'], bins_Max_Elevation)

# %%
df_airplane_bin = df_airplane.drop(columns=['Cabin_Temperature','Safety_Score','Days_Since_Inspection','Total_Safety_Complaints','Control_Metric','Turbulence_In_gforces','Adverse_Weather_Metric','Max_Elevation'])
df_airplane_bin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 7570 to 9387
# Data columns (total 11 columns):
# Severity                       10000 non-null object
# Accident_Type_Code             10000 non-null object
# Violations                     10000 non-null int64
# Cabin_Temperature_Bin          9997 non-null category
# Days_Since_Inspection_Bin      9995 non-null category
# Total_Safety_Complaints_Bin    8719 non-null category
# Control_Metric_Bin             9997 non-null category
# Turbulence_In_gforces_Bin      9992 non-null category
# Adverse_Weather_Metric_Bin     9999 non-null category
# Max_Elevation_Bin              9991 non-null category
# Safety_Score_Bin               9995 non-null category
# dtypes: category(8), int64(1), object(2)
# memory usage: 394.2+ KB

# %%
df_airplane_bin.head()
# Out:
#                                             Severity Accident_Type_Code  \
# Accident_ID
# 7570                       Minor_Damage_And_Injuries                  2
# 12128                      Minor_Damage_And_Injuries                  2
# 2181               Significant_Damage_And_Fatalities                  7
# 5946         Significant_Damage_And_Serious_Injuries                  3
# 9054               Significant_Damage_And_Fatalities                  3
#
#              Violations Cabin_Temperature_Bin Days_Since_Inspection_Bin  \
# Accident_ID
# 7570                  3         (77.27, 79.8]          (13.222, 15.667]
# 12128                 2        (82.33, 84.86]           (8.333, 10.778]
# 2181                  3         (77.27, 79.8]          (10.778, 13.222]
# 5946                  1         (79.8, 82.33]          (10.778, 13.222]
# 9054                  2        (74.74, 77.27]          (10.778, 13.222]
#
#             Total_Safety_Complaints_Bin Control_Metric_Bin  \
# ...

# %%
df_airplane_bin.isnull().sum()
# Out:
# Severity                          0
# Accident_Type_Code                0
# Violations                        0
# Cabin_Temperature_Bin             3
# Days_Since_Inspection_Bin         5
# Total_Safety_Complaints_Bin    1281
# Control_Metric_Bin                3
# Turbulence_In_gforces_Bin         8
# Adverse_Weather_Metric_Bin        1
# Max_Elevation_Bin                 9
# Safety_Score_Bin                  5
# dtype: int64

# %%
df_airplane_bin.dropna(axis=0,inplace=True)
df_airplane_bin.isnull().sum()
# Out:
# Severity                       0
# Accident_Type_Code             0
# Violations                     0
# Cabin_Temperature_Bin          0
# Days_Since_Inspection_Bin      0
# Total_Safety_Complaints_Bin    0
# Control_Metric_Bin             0
# Turbulence_In_gforces_Bin      0
# Adverse_Weather_Metric_Bin     0
# Max_Elevation_Bin              0
# Safety_Score_Bin               0
# dtype: int64

# %%
df_airplane_bin.shape
# Out:
# (8694, 11)

# %% [markdown]
# ### Model Building

# %%
X=df_airplane_bin.loc[:,~df_airplane_bin.columns.isin(['Severity'])]
y=df_airplane_bin.loc[:,'Severity']
print(X.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8694 entries, 7570 to 9387
# Data columns (total 10 columns):
# Accident_Type_Code             8694 non-null object
# Violations                     8694 non-null int64
# Cabin_Temperature_Bin          8694 non-null category
# Days_Since_Inspection_Bin      8694 non-null category
# Total_Safety_Complaints_Bin    8694 non-null category
# Control_Metric_Bin             8694 non-null category
# Turbulence_In_gforces_Bin      8694 non-null category
# Adverse_Weather_Metric_Bin     8694 non-null category
# Max_Elevation_Bin              8694 non-null category
# Safety_Score_Bin               8694 non-null category
# dtypes: category(8), int64(1), object(1)
# memory usage: 275.3+ KB
# None

# %%
X_dummy = pd.get_dummies(X,drop_first=True,prefix_sep='_')
X_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8694 entries, 7570 to 9387
# Data columns (total 71 columns):
# Violations                                    8694 non-null int64
# Accident_Type_Code_2                          8694 non-null uint8
# Accident_Type_Code_3                          8694 non-null uint8
# Accident_Type_Code_4                          8694 non-null uint8
# Accident_Type_Code_5                          8694 non-null uint8
# Accident_Type_Code_6                          8694 non-null uint8
# Accident_Type_Code_7                          8694 non-null uint8
# Cabin_Temperature_Bin_(77.27, 79.8]           8694 non-null uint8
# Cabin_Temperature_Bin_(79.8, 82.33]           8694 non-null uint8
# Cabin_Temperature_Bin_(82.33, 84.86]          8694 non-null uint8
# Cabin_Temperature_Bin_(84.86, 87.39]          8694 non-null uint8
# Cabin_Temperature_Bin_(87.39, 89.92]          8694 non-null uint8
# Cabin_Temperature_Bin_(89.92, 92.45]          8694 non-null uint8
# ...

# %%
X_dummy.shape
# Out:
# (8694, 71)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummy, y, test_size=0.30, random_state=42)

# %%
## Import the random forest model.
from sklearn.ensemble import RandomForestClassifier 

## This line instantiates the model. 
rf = RandomForestClassifier(n_estimators=300) 

## Fit the model on your training data.
rf.fit(X_train, y_train) 

## And score it on your testing data.
rf.score(X_test, y_test)
# Out:
# 0.810272134917593

# %%
import pandas as pd
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                   columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#                                             importance
# Control_Metric_Bin_(44.444, 55.556]           0.056881
# Violations                                    0.053730
# Days_Since_Inspection_Bin_(15.667, 18.111]    0.039597
# Days_Since_Inspection_Bin_(10.778, 13.222]    0.036410
# Days_Since_Inspection_Bin_(13.222, 15.667]    0.033016
# ...                                                ...
# Cabin_Temperature_Bin_(89.92, 92.45]          0.000199
# Total_Safety_Complaints_Bin_(48.0, 54.0]      0.000102
# Cabin_Temperature_Bin_(92.45, 94.98]          0.000067
# Cabin_Temperature_Bin_(94.98, 97.51]          0.000066
# Adverse_Weather_Metric_Bin_(2.103, 2.365]     0.000065
#
# [71 rows x 1 columns]

# %%
from sklearn import metrics as sm
pred = rf.predict(X_test)
print(sm.accuracy_score(y_test,pred))
print(sm.classification_report(y_test,pred))
# Out:
# 0.810272134917593
#                                          precision    recall  f1-score   support
#
#               Highly_Fatal_And_Damaging       0.82      0.84      0.83       802
#               Minor_Damage_And_Injuries       0.78      0.78      0.78       638
#       Significant_Damage_And_Fatalities       0.83      0.78      0.80       445
# Significant_Damage_And_Serious_Injuries       0.82      0.83      0.82       724
#
#                             avg / total       0.81      0.81      0.81      2609

# %%
## reading test dataframe

test_submission = pd.read_csv('test.csv')
test_submission.set_index('Accident_ID',inplace=True)
test_submission.Accident_Type_Code = test_submission.Accident_Type_Code.astype('object')
test_submission['Safety_Score_Bin'] = pd.cut(test_submission['Safety_Score'], bins_Safety_Score)
test_submission['Days_Since_Inspection_Bin'] = pd.cut(test_submission['Days_Since_Inspection'], bins_Days_Since_Inspection)
test_submission['Total_Safety_Complaints_Bin'] = pd.cut(test_submission['Total_Safety_Complaints'], bins_Total_Safety_Complaints)
test_submission['Control_Metric_Bin'] = pd.cut(test_submission['Control_Metric'], bins_Control_Metric)
test_submission['Turbulence_In_gforces_Bin'] = pd.cut(test_submission['Turbulence_In_gforces'], bins_Turbulence_In_gforces)
test_submission['Adverse_Weather_Metric_Bin'] = pd.cut(test_submission['Adverse_Weather_Metric'], bins_Adverse_Weather_Metric)
test_submission['Max_Elevation_Bin'] = pd.cut(test_submission['Max_Elevation'], bins_Max_Elevation)
test_submission['Cabin_Temperature_Bin'] = pd.cut(test_submission['Cabin_Temperature'], bins)

test_submission.drop(columns=['Cabin_Temperature','Safety_Score','Days_Since_Inspection','Total_Safety_Complaints','Control_Metric','Turbulence_In_gforces','Adverse_Weather_Metric','Max_Elevation'],inplace=True)
test_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 1 to 12493
# Data columns (total 10 columns):
# Accident_Type_Code             2500 non-null object
# Violations                     2500 non-null int64
# Safety_Score_Bin               2497 non-null category
# Days_Since_Inspection_Bin      2499 non-null category
# Total_Safety_Complaints_Bin    2174 non-null category
# Control_Metric_Bin             2500 non-null category
# Turbulence_In_gforces_Bin      2500 non-null category
# Adverse_Weather_Metric_Bin     2500 non-null category
# Max_Elevation_Bin              2499 non-null category
# Cabin_Temperature_Bin          2498 non-null category
# dtypes: category(8), int64(1), object(1)
# memory usage: 81.8+ KB

# %%
test_submission.isnull().sum()
# Out:
# Accident_Type_Code               0
# Violations                       0
# Safety_Score_Bin                 3
# Days_Since_Inspection_Bin        1
# Total_Safety_Complaints_Bin    326
# Control_Metric_Bin               0
# Turbulence_In_gforces_Bin        0
# Adverse_Weather_Metric_Bin       0
# Max_Elevation_Bin                1
# Cabin_Temperature_Bin            2
# dtype: int64

# %%
for column in ['Safety_Score_Bin','Days_Since_Inspection_Bin','Total_Safety_Complaints_Bin','Max_Elevation_Bin','Cabin_Temperature_Bin']:
    test_submission[column].fillna(test_submission[column].mode()[0], inplace=True)
test_submission.isnull().sum()
# Out:
# Accident_Type_Code             0
# Violations                     0
# Safety_Score_Bin               0
# Days_Since_Inspection_Bin      0
# Total_Safety_Complaints_Bin    0
# Control_Metric_Bin             0
# Turbulence_In_gforces_Bin      0
# Adverse_Weather_Metric_Bin     0
# Max_Elevation_Bin              0
# Cabin_Temperature_Bin          0
# dtype: int64

# %%
test_submission.head()
# Out:
#              Accident_Type_Code  Violations  Safety_Score_Bin  \
# Accident_ID
# 1                             4           2  (11.111, 22.222]
# 10                            7           2  (55.556, 66.667]
# 14                            6           1  (22.222, 33.333]
# 17                            3           2     (0.0, 11.111]
# 21                            2           2     (0.0, 11.111]
#
#             Days_Since_Inspection_Bin Total_Safety_Complaints_Bin  \
# Accident_ID
# 1                    (15.667, 18.111]                  (0.0, 6.0]
# 10                   (13.222, 15.667]                  (0.0, 6.0]
# 14                   (13.222, 15.667]                  (0.0, 6.0]
# 17                     (20.556, 23.0]                  (0.0, 6.0]
# 21                   (15.667, 18.111]                  (0.0, 6.0]
#
#             Control_Metric_Bin Turbulence_In_gforces_Bin  \
# Accident_ID
# 1             (66.667, 77.778]            (0.384, 0.467]
# ...

# %%
len(test_submission.columns)
# Out:
# 10

# %%
len(X.columns)
# Out:
# 10

# %%
len(X_dummy.columns)
# Out:
# 71

# %%
test_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 1 to 12493
# Data columns (total 10 columns):
# Accident_Type_Code             2500 non-null object
# Violations                     2500 non-null int64
# Safety_Score_Bin               2500 non-null category
# Days_Since_Inspection_Bin      2500 non-null category
# Total_Safety_Complaints_Bin    2500 non-null category
# Control_Metric_Bin             2500 non-null category
# Turbulence_In_gforces_Bin      2500 non-null category
# Adverse_Weather_Metric_Bin     2500 non-null category
# Max_Elevation_Bin              2500 non-null category
# Cabin_Temperature_Bin          2500 non-null category
# dtypes: category(8), int64(1), object(1)
# memory usage: 81.8+ KB

# %%
test_submission_dummy= pd.get_dummies(test_submission,drop_first=True,prefix_sep='_')
len(test_submission_dummy.columns)
# Out:
# 71

# %%
pred_test_submission = rf.predict(test_submission_dummy)
test_submission_dummy['Severity'] = pred_test_submission
test_submission_dummy.reset_index(inplace=True)
final_df = test_submission_dummy[['Accident_ID','Severity']]
final_df.to_csv("predictions.csv",index=False,header=True)

# %% [markdown]
# ## Binning -- IGNORE

# %%
# Trying to build model without Feature Engineering

# %%
X=df_airplane.loc[:,~df_airplane.columns.isin(['Severity'])]
y=df_airplane.loc[:,'Severity']
print(X.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 7570 to 9387
# Data columns (total 10 columns):
# Safety_Score               10000 non-null float64
# Days_Since_Inspection      10000 non-null int64
# Total_Safety_Complaints    10000 non-null int64
# Control_Metric             10000 non-null float64
# Turbulence_In_gforces      10000 non-null float64
# Cabin_Temperature          10000 non-null float64
# Accident_Type_Code         10000 non-null object
# Max_Elevation              10000 non-null float64
# Violations                 10000 non-null int64
# Adverse_Weather_Metric     10000 non-null float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 859.4+ KB
# None

# %%
print(y.head())
# Out:
# Accident_ID
# 7570                   Minor_Damage_And_Injuries
# 12128                  Minor_Damage_And_Injuries
# 2181           Significant_Damage_And_Fatalities
# 5946     Significant_Damage_And_Serious_Injuries
# 9054           Significant_Damage_And_Fatalities
# Name: Severity, dtype: object

# %%
X_dummy = pd.get_dummies(X,drop_first=True,prefix_sep='_')
X_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 7570 to 9387
# Data columns (total 15 columns):
# Safety_Score               10000 non-null float64
# Days_Since_Inspection      10000 non-null int64
# Total_Safety_Complaints    10000 non-null int64
# Control_Metric             10000 non-null float64
# Turbulence_In_gforces      10000 non-null float64
# Cabin_Temperature          10000 non-null float64
# Max_Elevation              10000 non-null float64
# Violations                 10000 non-null int64
# Adverse_Weather_Metric     10000 non-null float64
# Accident_Type_Code_2       10000 non-null uint8
# Accident_Type_Code_3       10000 non-null uint8
# Accident_Type_Code_4       10000 non-null uint8
# Accident_Type_Code_5       10000 non-null uint8
# Accident_Type_Code_6       10000 non-null uint8
# Accident_Type_Code_7       10000 non-null uint8
# dtypes: float64(6), int64(3), uint8(6)
# memory usage: 839.8 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummy, y, test_size=0.30, random_state=42)

# %%
#1. Random Forest

# %%
## Import the random forest model.
from sklearn.ensemble import RandomForestClassifier 

## This line instantiates the model. 
rf = RandomForestClassifier(n_estimators=300) 

## Fit the model on your training data.
rf.fit(X_train, y_train) 

## And score it on your testing data.
rf.score(X_test, y_test)
# Out:
# 0.8703333333333333

# %%
import pandas as pd
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                   columns=['importance']).sort_values('importance',ascending=False)
feature_importances
# Out:
#                          importance
# Safety_Score               0.212372
# Days_Since_Inspection      0.167834
# Control_Metric             0.156377
# Adverse_Weather_Metric     0.094195
# Turbulence_In_gforces      0.069581
# Cabin_Temperature          0.055025
# Max_Elevation              0.050075
# Accident_Type_Code_3       0.043920
# Total_Safety_Complaints    0.042374
# Violations                 0.023312
# Accident_Type_Code_2       0.022777
# Accident_Type_Code_6       0.021142
# Accident_Type_Code_7       0.020213
# Accident_Type_Code_4       0.016302
# Accident_Type_Code_5       0.004501

# %%
from sklearn import metrics as sm
pred = rf.predict(X_test)
print(sm.accuracy_score(y_test,pred))
# Out:
# 0.8703333333333333

# %%
print(sm.classification_report(y_test,pred))
# Out:
#                                          precision    recall  f1-score   support
#
#               Highly_Fatal_And_Damaging       0.91      0.88      0.90       913
#               Minor_Damage_And_Injuries       0.80      0.88      0.83       747
#       Significant_Damage_And_Fatalities       0.89      0.85      0.87       487
# Significant_Damage_And_Serious_Injuries       0.89      0.86      0.87       853
#
#                             avg / total       0.87      0.87      0.87      3000

# %%
pred
# Out:
# array(['Minor_Damage_And_Injuries', 'Significant_Damage_And_Fatalities',
#        'Significant_Damage_And_Fatalities', ...,
#        'Significant_Damage_And_Serious_Injuries',
#        'Significant_Damage_And_Serious_Injuries',
#        'Highly_Fatal_And_Damaging'], dtype=object)

# %%
y_test.head()
# Out:
# Accident_ID
# 11997                  Minor_Damage_And_Injuries
# 6283           Significant_Damage_And_Fatalities
# 9211           Significant_Damage_And_Fatalities
# 9827                   Highly_Fatal_And_Damaging
# 7564     Significant_Damage_And_Serious_Injuries
# Name: Severity, dtype: object

# %% [markdown]
# ## Submission

# %%
## reading test dataframe

test_submission = pd.read_csv('test.csv')
test_submission.head()
# Out:
#    Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0     19.497717                     16                        6
# 1     58.173516                     15                        3
# 2     33.287671                     15                        3
# 3      3.287671                     21                        5
# 4     10.867580                     18                        2
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  \
# 0       72.151322               0.388959              78.32
# 1       64.585232               0.250841              78.60
# 2       64.721969               0.336669              86.96
# 3       66.362808               0.421775              80.86
# 4       56.107566               0.313228              79.22
#
#    Accident_Type_Code  Max_Elevation  Violations  Adverse_Weather_Metric  \
# 0                   4   37949.724386           2                0.069692
# ...

# %%
test_submission.set_index('Accident_ID',inplace=True)

# %%
test_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 1 to 12493
# Data columns (total 10 columns):
# Safety_Score               2500 non-null float64
# Days_Since_Inspection      2500 non-null int64
# Total_Safety_Complaints    2500 non-null int64
# Control_Metric             2500 non-null float64
# Turbulence_In_gforces      2500 non-null float64
# Cabin_Temperature          2500 non-null float64
# Accident_Type_Code         2500 non-null int64
# Max_Elevation              2500 non-null float64
# Violations                 2500 non-null int64
# Adverse_Weather_Metric     2500 non-null float64
# dtypes: float64(6), int64(4)
# memory usage: 214.8 KB

# %%
test_submission.Accident_Type_Code = test_submission.Accident_Type_Code.astype('object')
test_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 1 to 12493
# Data columns (total 10 columns):
# Safety_Score               2500 non-null float64
# Days_Since_Inspection      2500 non-null int64
# Total_Safety_Complaints    2500 non-null int64
# Control_Metric             2500 non-null float64
# Turbulence_In_gforces      2500 non-null float64
# Cabin_Temperature          2500 non-null float64
# Accident_Type_Code         2500 non-null object
# Max_Elevation              2500 non-null float64
# Violations                 2500 non-null int64
# Adverse_Weather_Metric     2500 non-null float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 214.8+ KB

# %%
test_submission_dummy= pd.get_dummies(test_submission,drop_first=True,prefix_sep='_')

# %%
pred_test_submission = rf.predict(test_submission_dummy)
type(pred_test_submission)
# Out:
# numpy.ndarray

# %%
len(pred_test_submission)
# Out:
# 2500

# %%
test_submission_dummy['Severity'] = pred_test_submission

# %%
test_submission_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 1 to 12493
# Data columns (total 16 columns):
# Safety_Score               2500 non-null float64
# Days_Since_Inspection      2500 non-null int64
# Total_Safety_Complaints    2500 non-null int64
# Control_Metric             2500 non-null float64
# Turbulence_In_gforces      2500 non-null float64
# Cabin_Temperature          2500 non-null float64
# Max_Elevation              2500 non-null float64
# Violations                 2500 non-null int64
# Adverse_Weather_Metric     2500 non-null float64
# Accident_Type_Code_2       2500 non-null uint8
# Accident_Type_Code_3       2500 non-null uint8
# Accident_Type_Code_4       2500 non-null uint8
# Accident_Type_Code_5       2500 non-null uint8
# Accident_Type_Code_6       2500 non-null uint8
# Accident_Type_Code_7       2500 non-null uint8
# Prediction                 2500 non-null object
# dtypes: float64(6), int64(3), object(1), uint8(6)
# memory usage: 229.5+ KB

# %%
test_submission_dummy[['Severity']]
# Out:
#                                             Severity
# Accident_ID
# 1                          Highly_Fatal_And_Damaging
# 10                 Significant_Damage_And_Fatalities
# 14           Significant_Damage_And_Serious_Injuries
# 17                         Highly_Fatal_And_Damaging
# 21                 Significant_Damage_And_Fatalities
# ...                                              ...
# 12484                      Highly_Fatal_And_Damaging
# 12487        Significant_Damage_And_Serious_Injuries
# 12488        Significant_Damage_And_Serious_Injuries
# 12491        Significant_Damage_And_Serious_Injuries
# 12493                      Highly_Fatal_And_Damaging
#
# [2500 rows x 1 columns]

# %%
test_submission_dummy.bkp = test_submission_dummy.copy()
# Out:
# C:\Users\PB5062657\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
test_submission_dummy.reset_index(inplace=True)
test_submission_dummy.head()
# Out:
#    Accident_ID  Safety_Score  Days_Since_Inspection  Total_Safety_Complaints  \
# 0            1     19.497717                     16                        6
# 1           10     58.173516                     15                        3
# 2           14     33.287671                     15                        3
# 3           17      3.287671                     21                        5
# 4           21     10.867580                     18                        2
#
#    Control_Metric  Turbulence_In_gforces  Cabin_Temperature  Max_Elevation  \
# 0       72.151322               0.388959              78.32   37949.724386
# 1       64.585232               0.250841              78.60   30194.805567
# 2       64.721969               0.336669              86.96   17572.925484
# 3       66.362808               0.421775              80.86   40209.186341
# 4       56.107566               0.313228              79.22   35495.525408
#
# ...

# %%
final_df = test_submission_dummy[['Accident_ID','Severity']]
final_df.head()
# Out:
#    Accident_ID                                 Severity
# 0            1                Highly_Fatal_And_Damaging
# 1           10        Significant_Damage_And_Fatalities
# 2           14  Significant_Damage_And_Serious_Injuries
# 3           17                Highly_Fatal_And_Damaging
# 4           21        Significant_Damage_And_Fatalities

# %%
final_df.to_csv("predictions.csv",index=False,header=True)
